# %%
import random

# %%
labeled_examples = [
"""
Text: i båda fallen är modern genetisk mor till barnet .
Label: not_applicable

Text: i de fall socialnämnden inte tar sitt ansvar eller inte lyckas , måste det ändå finnas rätt för nära anhöriga , som mor- och farföräldrar , att hos tingsrätten föra talan om umgänge .
Label: not_applicable

Text: det finns en överrepresentation bland fäder med låg utbildning , låg inkomst och pappor med utländsk bakgrund .
Label: passive

Text: visserligen är det obalans i uttaget av föräldraförsäkringen , men samtidigt är det viktigt att slå fast att fler pappor i dag tar ut föräldraledighet än före införandet av mamma- och pappamånaden .
Label: active_positive_other

Text: om barnets föräldrar varken är gifta eller registrerade samman- boende vid barnets födelse är mamman ensam vårdnadshavare .
Label: passive

Text: bland dem fanns män , kvinnor och barn , unga och gamla , fäder och mödrar , söner och döttrar , makar och syskon .
Label: not_applicable

Text: lagutskottet har tidigare anfört att man anser att den nuvarande ordningen ger betryggande garantier för att det verkligen är den biologiske fadern och inte någon annan som fastställs som far till ett barn ( 0000/00 : lu0 ) .
Label: passive

Text: i isf : s rapport dubbeldagar – pappors väg in i föräldrapenningen dras slutsatsen att pappors uttag under barnets första levnadsår har ökat och att pappor som tidigare valt att ej ta ut föräldrapenning nu börjat ta ut dagar .
Label: active_positive_other

Text: som förutsättning för alt barnavårdsnämnden skall vara skyldig att utreda om annan än den äkta mannen kan vara fader uppställer förslaget - utom att bamet skall ha viss anknytning lill sverige - dels att utredningen skall ha begärts av vårdnadshavare för barnet , d , v , s , normalt modern , eller av den äkta mannen , dels att det skall finnas lämpligt .
Label: passive

Text: genom projektet `` läs för mig pappa '' , knutet till arbetsplatsbibliotek , uppmuntras fäder att både läsa själva och att läsa för sina barn .
Label: active_positive_challenging

Text: någon skyldighet att godkänna en utländsk dom om moderskap för barnets sociala eller genetiska mor , eller en utländsk dom om faderskap för en genetisk fars manliga partner , kan däremot inte utläsas av domstolens hittill- svarande praxis .
Label: passive

Text: här uppmanas pappor också att ta ett ansvar som läsande fäder .
Label: active_positive_challenging

Text: av barnens svar kan man utläsa att mammor generellt har mer tid för sina barn oavsett i vilken utsträckning de bor med mamma , medan för barnen kan det ge mer tid med pappa när föräldrarna separerar än när de bor ihop under förutsättning att de minst bor halva tiden med pappan .
Label: active_positive_other

Text: det är fullt möjligt att kommunicera kring varför för- äldraskapet så lätt upplevs som något som angår mamman mer än pappan , varför pappor kan känna sig som tillräckligt goda fäder trots ett mycket lågt uttag av föräldraledighet , varför mammor ofta tror att de är bättre på att läsa av barnet än vad pappor är , varför pappor uppfattas som hjältar när de gör samma sak som mammor gör av bara farten och tusen andra frågor som har att göra med för- äldraskapet som bekönad position .
Label: active_positive_caring

Text: då utmålas oftast pappan som hotfull , våldsam och som en dålig förälder .
Label: active_negative

Text: det vanliga är sedan att våldtäktsmannen -- om det inte var fadern eller en nära släkting som förövat dådet -- betalar flickans föräldrar för att de inte skall anmäla fallet till polisen .
Label: active_negative

Text: för att underlätta för framför allt fäder att öka sitt uttag av föräldrapen­ning föreslås att ersättningen utges med sjukpenningens belopp oberoende av den andre förälderns sjukpenning .
Label: active_positive_other

Text: ha föräldrar gemensamt barn i sin värd , utgår föräldrapenning över garanlinivån lill fadern endast under förutsättning att även modern är eller enligt vad förut sagts bort vara försäkrad för sjukpenning som överstiger garantinivån .
Label: passive
"""
]

# separate each test-label couple from the others
labeled_examples = labeled_examples[0].split("\n\n")
# remove leading and trailing newlines
labeled_examples = [example.strip("\n") for example in labeled_examples]
# remove leading and trailing whitespaces
labeled_examples = [example.strip() for example in labeled_examples]

# %%
random.seed(512)

# shuffle the list in place
random.shuffle(labeled_examples)

shuffled_labeled_examples = "\n\n".join(labeled_examples)

print(shuffled_labeled_examples)
print("-"*80)

with open("../data/human_annotation/labeled_examples_1.txt", "w") as f:
    f.write(shuffled_labeled_examples)

# shuffle the list AGAIN
random.shuffle(labeled_examples)

shuffled_labeled_examples = "\n\n".join(labeled_examples)

print(shuffled_labeled_examples)

with open("../data/human_annotation/labeled_examples_2.txt", "w") as f:
    f.write(shuffled_labeled_examples)
# Out:
# Text: det vanliga är sedan att våldtäktsmannen -- om det inte var fadern eller en nära släkting som förövat dådet -- betalar flickans föräldrar för att de inte skall anmäla fallet till polisen .
# Label: active_negative
#
# Text: någon skyldighet att godkänna en utländsk dom om moderskap för barnets sociala eller genetiska mor , eller en utländsk dom om faderskap för en genetisk fars manliga partner , kan däremot inte utläsas av domstolens hittill- svarande praxis .
# Label: passive
#
# Text: här uppmanas pappor också att ta ett ansvar som läsande fäder .
# Label: active_positive_challenging
#
# Text: i isf : s rapport dubbeldagar – pappors väg in i föräldrapenningen dras slutsatsen att pappors uttag under barnets första levnadsår har ökat och att pappor som tidigare valt att ej ta ut föräldrapenning nu börjat ta ut dagar .
# Label: active_positive_other
#
# ...

# %%
# !pwd
# Out:
# /Users/llupo/dev/pappa/notebooks
