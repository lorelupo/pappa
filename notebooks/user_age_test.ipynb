# %%
import pandas as pd

# %%
# read pkl file
path= "../data/user_age_classification_dataset.pkl"
df = pd.read_pickle(path)
df
# Out:
#                   user_id         username                full_name  \
# 0     1332386165484367873       MassimoEdi  editulliomassimomecchia
# 1      828058728536621056    zittononcisto            zittononcisto
# 2                50643045        pcognetti           paolo cognetti
# 3     1328744192420540417       ludofedeli                     ludo
# 4     1245767274595844096       FiaccolaLa              la fiaccola
# ...                   ...              ...                      ...
# 9382   965243268127776768  valenti89488974                valentina
# 9383            386009135  GIORGIOMORRETTA         giorgio morretta
# 9384            100734769          LaTokka                    marts
# 9385            986655998          enry96_                     enry
# 9386            557719823     IlariaGallon                   ilaria
#
#                                                     bio  \
# 0     ‏𝓥𝓸𝓵𝓸𝓷𝓽𝓪𝓻𝓲𝓸 𝓲𝓷 𝓾𝓻𝓰𝓮𝓷𝔃𝓪 𝓮𝓶𝓮𝓻𝓰𝓮𝓷𝔃𝓪 𝓭𝓪𝓵 1976\r\nמ...
# ...

# %%
print(df.iloc[9].bio)
# find how many times the text "tweeted in" is contained in the string field text_and_year
print(df.iloc[3].bio.count("GIORGIA"))
# Out:
# siamo nati come azienda agricola nel 1986 ed oggi siamo proprietari di ha32 di oliveto con oltre 16.000 olivi BIO dal 1996 e consegnamo in tutta Europa!
# 0
