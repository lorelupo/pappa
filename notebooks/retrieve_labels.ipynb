# %%
import collections
import pandas as pd
import numpy as np
import sys
path = '/Users/llupo/dev/pappa'
if not path in sys.path :
    sys.path.append(path)

from classifiers import LMClassifier
from task_manager import TaskManager

# %%
import os

#output_dir = '/Users/llupo/dev/pappa/results/pappa/alldim/alldata_long_fewshot_text-davinci-003'
output_dir = '/Users/llupo/dev/pappa/results/pappa/alldim/alldata_long_fewshot_gpt-4'

with open(os.path.join(output_dir, 'raw_predictions.txt'), 'r') as f:
    predictions = f.read().splitlines()

print(len(predictions))
print(predictions[:5])
# Out:
# 1910
# ['passive, explicit, descriptive', 'passive, explicit, descriptive', 'active_positive_other, explicit, ideal', 'active_positive_other, explicit, ideal', 'active_positive_other, explicit, ideal']

# %%
from logging import getLogger
logger = getLogger(__name__)

class LMClassifier:
    def __init__(
            self,
            labels_dict,
            label_dims,
            default_label,
            ):

        self.labels_dict = labels_dict
        # check the dimensionality of the labels:
        # dimensionality greater than 1 means dealing with
        # multiple classification tasks at a time
        self.label_dims = label_dims
        assert self.label_dims > 0, "Labels dimensions must be greater than 0."
        self.default_label = default_label

    def generate_predictions(self):
        raise NotImplementedError
    
    def retrieve_predicted_labels(self, predictions, prompts, only_dim=None):

        # convert the predictions to lowercase
        predictions =  list(map(str.lower,predictions))

        # retrieve the labels that are contained in the predictions
        predicted_labels = []
        if self.label_dims == 1:
            # retrieve a single label for each prediction since a single classification task is performed at a time
            logger.info("Retrieving predictions...")
            for prediction in predictions:
                labels_in_prediction = [self.labels_dict.get(label) for label in self.labels_dict.keys() if label in prediction]
                if len(labels_in_prediction) > 0:
                    predicted_labels.append(labels_in_prediction[0])
                else:
                    predicted_labels.append(self.labels_dict.get(self.default_label))
            # Count the number of predictions of each type and print the result
            logger.info(collections.Counter(predicted_labels))
        else:
            # retrieve multiple labels for each prediction since multiple classification tasks are performed at a time
            logger.info(f"Retrieving predictions for {self.label_dims} dimensions...")
            for prediction in predictions:
                labels_in_prediction = []
                for dim in self.labels_dict.keys():
                    dim_label = []
                    for label in self.labels_dict[dim].keys():
                        if label in prediction:
                            dim_label.append(self.labels_dict[dim].get(label))   
                    dim_label = dim_label[0] if len(dim_label) > 0 else self.labels_dict[dim].get(self.default_label)
                    labels_in_prediction.append(dim_label)                                            
                predicted_labels.append(labels_in_prediction)
            # Count the number of predictions of each type and print the result
            logger.info(collections.Counter([",".join(labels) for labels in predicted_labels]))
        
        # Add the data to a DataFrame
        if self.label_dims == 1:
            df = pd.DataFrame({'prompt': prompts, 'prediction': predicted_labels})
        elif self.label_dims > 1:
            if only_dim is not None:
                # retrieve only the predictions for a specific dimension
                logger.info(f"Retrieved predictions for dimension {only_dim}")
                df = pd.DataFrame({'prompt': prompts, 'prediction': pd.DataFrame(predicted_labels).to_numpy()[:,only_dim]})
            else:
                logger.info("Retrieved predictions for all dimensions")
                df = pd.DataFrame(predicted_labels).fillna(self.default_label)
                # rename columns to prediction_n
                df.columns = [f"prediction_dim{i}" for i in range(1, len(df.columns)+1)]
                # add prompts to df
                df['prompt'] = prompts

        return df

labels_dict = {
    "label_dims": 3,
    "labels": {
        "dim1": {
            "not_applicable": "NA",
            "passive": "PASSIVE",
            "active_negative": "ACTIVE_NEG",
            "active_positive_challenging": "ACTIVE_POS_CHALLENGING",
            "active_positive_caring": "ACTIVE_POS_CARING",
            "active_positive_other": "ACTIVE_POS_OTHER"
        },
        "dim2": {
            "not_applicable": "NA",
            "explicit": "EXPLICIT",
            "implicit": "IMPLICIT"
        },
        "dim3": {
            "not_applicable": "NA",
            "descriptive": "DESCRIPTIVE",
            "ideal": "IDEAL"
        }
    },
    "read_function": "pappa"
}

default_label='NA'
labels_allowed=3

classifier = LMClassifier(
    labels_dict=labels_dict['labels'],
    label_dims=labels_dict['label_dims'],
    default_label="not_applicable"
    )

df_predicted_labels = classifier.retrieve_predicted_labels(
    predictions=predictions,
    prompts=None,
    only_dim=None
    )

df_predicted_labels
# Out:
#         prediction_dim1 prediction_dim2 prediction_dim3 prompt
# 0               PASSIVE        EXPLICIT     DESCRIPTIVE   None
# 1               PASSIVE        EXPLICIT     DESCRIPTIVE   None
# 2      ACTIVE_POS_OTHER        EXPLICIT           IDEAL   None
# 3      ACTIVE_POS_OTHER        EXPLICIT           IDEAL   None
# 4      ACTIVE_POS_OTHER        EXPLICIT           IDEAL   None
# ...                 ...             ...             ...    ...
# 1905  ACTIVE_POS_CARING        IMPLICIT     DESCRIPTIVE   None
# 1906   ACTIVE_POS_OTHER        IMPLICIT     DESCRIPTIVE   None
# 1907         ACTIVE_NEG        EXPLICIT     DESCRIPTIVE   None
# 1908         ACTIVE_NEG        EXPLICIT     DESCRIPTIVE   None
# 1909                 NA              NA              NA   None
#
# [1910 rows x 4 columns]

# %%
path_data='/Users/llupo/dev/pappa/data/pappa/F_sample_clean_after1993.xlsx'
pd_data = pd.read_excel(path_data, engine='openpyxl')
pd_data.shape
# Out:
# (1910, 19)

# %%
# outer join dataframes on index
df_join = df_predicted_labels.merge(pd_data, how='outer', left_index=True, right_index=True)
print(df_join.shape)
df_join.tail(20)
# Out:
# (1910, 23)
#         prediction_dim1 prediction_dim2 prediction_dim3 prompt  Unnamed: 0  \
# 1890   ACTIVE_POS_OTHER        EXPLICIT     DESCRIPTIVE   None      360779
# 1891            PASSIVE        EXPLICIT     DESCRIPTIVE   None      360783
# 1892   ACTIVE_POS_OTHER        EXPLICIT     DESCRIPTIVE   None      361787
# 1893            PASSIVE        EXPLICIT           IDEAL   None      361789
# 1894   ACTIVE_POS_OTHER        EXPLICIT           IDEAL   None      361791
# 1895   ACTIVE_POS_OTHER        EXPLICIT           IDEAL   None      361794
# 1896   ACTIVE_POS_OTHER        EXPLICIT     DESCRIPTIVE   None      362347
# 1897            PASSIVE        IMPLICIT     DESCRIPTIVE   None      362443
# 1898  ACTIVE_POS_CARING        IMPLICIT     DESCRIPTIVE   None      362773
# 1899  ACTIVE_POS_CARING        EXPLICIT     DESCRIPTIVE   None      362774
# 1900            PASSIVE        EXPLICIT     DESCRIPTIVE   None      362896
# 1901         ACTIVE_NEG        EXPLICIT     DESCRIPTIVE   None      364119
# 1902         ACTIVE_NEG        IMPLICIT     DESCRIPTIVE   None      364124
# 1903   ACTIVE_POS_OTHER        EXPLICIT     DESCRIPTIVE   None      364159
# 1904   ACTIVE_POS_OTHER        EXPLICIT     DESCRIPTIVE   None      364182
# 1905  ACTIVE_POS_CARING        IMPLICIT     DESCRIPTIVE   None      364767
# 1906   ACTIVE_POS_OTHER        IMPLICIT     DESCRIPTIVE   None      364782
# 1907         ACTIVE_NEG        EXPLICIT     DESCRIPTIVE   None      364834
# 1908         ACTIVE_NEG        EXPLICIT     DESCRIPTIVE   None      364835
# 1909                 NA              NA              NA   None      364849
#
#                                              text_clean   filename  year  \
# 1890  bland annat har riksdagen beslutat om att förl...  gp05sfu1y  2001
# 1891  underhållsstödet bör enligt vår mening ersätta...  gp05sfu1y  2001
# 1892  inom ramen för den förlängda föräldraförsäkrin...  gn05sfu7y  1999
# 1893  vidare föreslås att ensamstående mödrar bör ku...  gn05sfu7y  1999
# 1894  vad gäller förslag om att ensamstående mödrar ...  gn05sfu7y  1999
# 1895  vad gäller förslag om att ensamstående mödrar ...  gn05sfu7y  1999
# 1896  resultaten pekade på att när det gäller transp...  h70wrfr10  2019
# 1897  hans pappa skulle gå och hälsa på sin bästa ko...   h80wrfr9  2020
# 1898  om barnet dör verkar dock fäder på lång sikt k...  h30wrfr13  2015
# 1899  en ny svensk studie visar att en större andel ...  h30wrfr13  2015
# 1900  det har belysts på många olika sätt , och jag ...  h30wrfr27  2015
# 1901  många mejl handlar också om att den ena föräld...  h10wrfr18  2013
# 1902  barnet vill helt enkelt inte vara hos pappa va...  h10wrfr18  2013
# 1903  vi ser att om mamman , vilket oftast är fallet...   h10wrfr9  2013
# 1904  det jag kan säga generellt om pappors uttag är...   h10wrfr9  2013
# 1905  i de fall där pappan döms till fängelse finns ...   gw0wrfr9  2008
# 1906  när det gäller familjehemsplacerade barn som b...   gw0wrfr9  2008
# 1907  kontaktuppgifter titti.mattson @ jur.lu.se 000...   gx0wrfr3  2009
# 1908  syfte att ge fördjupad kunskap om hur barn med...   gx0wrfr3  2009
# 1909  kontaktuppgifter eva.henriksen @ sll.se 00-000...   gx0wrfr3  2009
#
#       category                                        text_lemmas  ...  \
# 1890  Yttrande  riksdag förlänga föräldrapenning 00 ersättning...  ...
# 1891  Yttrande  underhållsstöde böra mening ersätta ensamståen...  ...
# 1892  Yttrande  ram förlänga föräldraförsäkring sammanlagd 00 ...  ...
# 1893  Yttrande  föreslå ensamstående böra överlåta ` ` pappada...  ...
# 1894  Yttrande  förslag ensamstående böra överlåta ` ` pappada...  ...
# 1895  Yttrande  förslag ensamstående böra överlåta ` ` pappada...  ...
# 1896    Övrigt  resultat peka transportval vara förebild döttr...  ...
# 1897    Övrigt                hälsa bra kompis pappa försvann tid  ...
# 1898    Övrigt  barn dö verka far lång sikt drabba psykisk ohä...  ...
# 1899    Övrigt  ny svensk studie visa andel far lida posttraum...  ...
# 1900    Övrigt  belys sätt väldig konkret modern dö far skrivi...  ...
# 1901    Övrigt  mejl handla ena förälder regel pappa fungera b...  ...
# 1902    Övrigt  barn hos varannan vecka varannan helg vara var...  ...
# 1903    Övrigt  se mamma vara fall först ta ganska pappa börja...  ...
# 1904    Övrigt  generell pappa uttag vara ta mängd föräldraled...  ...
# 1905    Övrigt  fall pappa döma fängelse försöka återställa or...  ...
# 1906    Övrigt  familjehemsplacerad barn bo anstalt förälder v...  ...
# 1907    Övrigt  kontaktuppgift titti.mattson jur.lu.se 000-000...  ...
# 1908    Övrigt  syfte ge fördjupa kunskap barn erfarenhet papp...  ...
# 1909    Övrigt  kontaktuppgift eva.henriks sll.se 00-000 000 0...  ...
#
#                     label_str               dim1      dim2         dim3  \
# 1890  FATHER, MOTHER, PARENTS            PASSIVE  EXPLICIT  DESCRIPTIVE
# 1891          FATHER, PARENTS   ACTIVE_POS_OTHER  EXPLICIT        IDEAL
# 1892  FATHER, MOTHER, PARENTS   ACTIVE_POS_OTHER  EXPLICIT        IDEAL
# 1893                   FATHER   ACTIVE_POS_OTHER  EXPLICIT        IDEAL
# 1894                   FATHER   ACTIVE_POS_OTHER  EXPLICIT        IDEAL
# 1895                   FATHER   ACTIVE_POS_OTHER  EXPLICIT        IDEAL
# 1896                   FATHER   ACTIVE_POS_OTHER  IMPLICIT  DESCRIPTIVE
# 1897                   FATHER                NaN       NaN  DESCRIPTIVE
# 1898                   FATHER            PASSIVE  EXPLICIT  DESCRIPTIVE
# 1899                   FATHER            PASSIVE  EXPLICIT  DESCRIPTIVE
# 1900          FATHER, PARENTS            PASSIVE  EXPLICIT  DESCRIPTIVE
# 1901          FATHER, PARENTS         ACTIVE_NEG  EXPLICIT  DESCRIPTIVE
# 1902                   FATHER                NaN       NaN          NaN
# 1903  FATHER, MOTHER, PARENTS   ACTIVE_POS_OTHER  EXPLICIT  DESCRIPTIVE
# 1904                   FATHER   ACTIVE_POS_OTHER  EXPLICIT  DESCRIPTIVE
# 1905                   FATHER  ACTIVE_POS_CARING  IMPLICIT  DESCRIPTIVE
# 1906  FATHER, MOTHER, PARENTS            PASSIVE  EXPLICIT  DESCRIPTIVE
# 1907          FATHER, PARENTS                NaN       NaN          NaN
# 1908                   FATHER                NaN       NaN          NaN
# 1909                   FATHER                NaN       NaN          NaN
#
#      election_period contains_FATHER contains_MOTHER  is_positive  \
# 1890            1998            True            True          0.0
# 1891            1998            True           False          1.0
# 1892            1998            True            True          1.0
# 1893            1998            True           False          1.0
# 1894            1998            True           False          1.0
# 1895            1998            True           False          1.0
# 1896            2018            True           False          1.0
# 1897            2018            True           False          0.0
# 1898            2014            True           False          0.0
# 1899            2014            True           False          0.0
# 1900            2014            True           False          0.0
# 1901            2010            True           False          0.0
# 1902            2010            True           False          0.0
# 1903            2010            True            True          1.0
# 1904            2010            True           False          1.0
# 1905            2006            True           False          1.0
# 1906            2006            True            True          0.0
# 1907            2006            True           False          0.0
# 1908            2006            True           False          0.0
# 1909            2006            True           False          0.0
#
#       dim1_reduced  dim1_binary
# 1890       PASSIVE       PASSIV
# 1891    ACTIVE_POS       ACTIVE
# 1892    ACTIVE_POS       ACTIVE
# 1893    ACTIVE_POS       ACTIVE
# 1894    ACTIVE_POS       ACTIVE
# 1895    ACTIVE_POS       ACTIVE
# 1896    ACTIVE_POS       ACTIVE
# 1897           NaN          NaN
# 1898       PASSIVE       PASSIV
# 1899       PASSIVE       PASSIV
# 1900       PASSIVE       PASSIV
# 1901    ACTIVE_NEG       ACTIVE
# 1902           NaN          NaN
# 1903    ACTIVE_POS       ACTIVE
# 1904    ACTIVE_POS       ACTIVE
# 1905    ACTIVE_POS       ACTIVE
# 1906       PASSIVE       PASSIV
# 1907           NaN          NaN
# 1908           NaN          NaN
# 1909           NaN          NaN
#
# [20 rows x 23 columns]

# %%
# save the dataframe
outpath='/Users/llupo/dev/pappa/data/pappa/F_sample_clean_after1993_gpt4predictions.xlsx'
df_join.to_excel(outpath, index=False)

# %%
df_predicted_labels = classifier.retrieve_predicted_labels(
    predictions=predictions,
    prompts=prompts,
    only_dim=only_dim
    )
