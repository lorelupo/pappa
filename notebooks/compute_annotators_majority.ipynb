# %%
import pandas as pd
import os
import sys
path = '/Users/llupo/dev/pappa'
if not path in sys.path :
    sys.path.append(path)

from lm_classifiers import LMClassifier
from task_manager import TaskManager

# %%
inpath1 = '../data/pappa/human_annotation/dim1.csv'
inpath2 = '../data/pappa/human_annotation/dim2.csv'
inpath3 = '../data/pappa/human_annotation/dim3.csv'


df1 = pd.read_csv(inpath1, sep=';').fillna('NA')
df2 = pd.read_csv(inpath2, sep=';').fillna('NA')
df3 = pd.read_csv(inpath3, sep=';').fillna('NA')

# compute the majority label from columns elin, lena, and oscar
df1['majority'] = df1[['elin', 'lena', 'oscar']].mode(axis=1)[0]
df2['majority'] = df2[['elin', 'lena', 'oscar']].mode(axis=1)[0]
df3['majority'] = df3[['elin', 'lena', 'oscar']].mode(axis=1)[0]

df1[['elin', 'lena', 'oscar', 'majority']].iloc[:20]

# Check if 'elin', 'lena', and 'oscar' contain different values in each row
different_values_mask = df1[['elin', 'lena', 'oscar']].apply(lambda row: len(set(row)) == len(row), axis=1)

# Retrieve rows where 'elin', 'lena', and 'oscar' contain different values
result_df = df1[different_values_mask][['elin', 'lena', 'oscar', 'majority']]

result_df # the df.mode() function returns the first value (alphabetical order) in case of ties
# Out:
#                  elin                    lena                   oscar  \
# 6                  NA        ACTIVE_POS_OTHER                 PASSIVE
# 9                  NA        ACTIVE_POS_OTHER                 PASSIVE
# 18                 NA              ACTIVE_NEG                 PASSIVE
# 23                 NA       ACTIVE_POS_CARING        ACTIVE_POS_OTHER
# 28         ACTIVE_NEG        ACTIVE_POS_OTHER                 PASSIVE
# 31                 NA                 PASSIVE  ACTIVE_POS_CHALLENGING
# 46   ACTIVE_POS_OTHER                 PASSIVE                      NA
# 60                 NA              ACTIVE_NEG                 PASSIVE
# 61         ACTIVE_NEG       ACTIVE_POS_CARING  ACTIVE_POS_CHALLENGING
# 62            PASSIVE  ACTIVE_POS_CHALLENGING        ACTIVE_POS_OTHER
# 98   ACTIVE_POS_OTHER              ACTIVE_NEG                      NA
# 146  ACTIVE_POS_OTHER                 PASSIVE                      NA
# 159  ACTIVE_POS_OTHER                 PASSIVE       ACTIVE_POS_CARING
# 161        ACTIVE_NEG        ACTIVE_POS_OTHER                 PASSIVE
# 164                NA                 PASSIVE        ACTIVE_POS_OTHER
# 184  ACTIVE_POS_OTHER                      NA       ACTIVE_POS_CARING
# 199  ACTIVE_POS_OTHER                 PASSIVE       ACTIVE_POS_CARING
# 202  ACTIVE_POS_OTHER  ACTIVE_POS_CHALLENGING       ACTIVE_POS_CARING
# 206  ACTIVE_POS_OTHER  ACTIVE_POS_CHALLENGING       ACTIVE_POS_CARING
# 210                NA                 PASSIVE        ACTIVE_POS_OTHER
# 223  ACTIVE_POS_OTHER                 PASSIVE       ACTIVE_POS_CARING
# 236        ACTIVE_NEG                 PASSIVE        ACTIVE_POS_OTHER
# 244        ACTIVE_NEG        ACTIVE_POS_OTHER                 PASSIVE
# 246  ACTIVE_POS_OTHER                 PASSIVE       ACTIVE_POS_CARING
# 288        ACTIVE_NEG        ACTIVE_POS_OTHER                 PASSIVE
# 298  ACTIVE_POS_OTHER                      NA  ACTIVE_POS_CHALLENGING
# 308  ACTIVE_POS_OTHER                 PASSIVE                      NA
# 336                NA              ACTIVE_NEG                 PASSIVE
# 338        ACTIVE_NEG        ACTIVE_POS_OTHER       ACTIVE_POS_CARING
#
#                    majority
# 6          ACTIVE_POS_OTHER
# 9          ACTIVE_POS_OTHER
# 18               ACTIVE_NEG
# 23        ACTIVE_POS_CARING
# 28               ACTIVE_NEG
# 31   ACTIVE_POS_CHALLENGING
# 46         ACTIVE_POS_OTHER
# 60               ACTIVE_NEG
# 61               ACTIVE_NEG
# 62   ACTIVE_POS_CHALLENGING
# 98               ACTIVE_NEG
# 146        ACTIVE_POS_OTHER
# 159       ACTIVE_POS_CARING
# 161              ACTIVE_NEG
# 164        ACTIVE_POS_OTHER
# 184       ACTIVE_POS_CARING
# 199       ACTIVE_POS_CARING
# 202       ACTIVE_POS_CARING
# 206       ACTIVE_POS_CARING
# 210        ACTIVE_POS_OTHER
# 223       ACTIVE_POS_CARING
# 236              ACTIVE_NEG
# 244              ACTIVE_NEG
# 246       ACTIVE_POS_CARING
# 288              ACTIVE_NEG
# 298  ACTIVE_POS_CHALLENGING
# 308        ACTIVE_POS_OTHER
# 336              ACTIVE_NEG
# 338              ACTIVE_NEG

# %%
inpath1 = '../data/pappa/human_annotation/dim1.csv'
inpath2 = '../data/pappa/human_annotation/dim2.csv'
inpath3 = '../data/pappa/human_annotation/dim3.csv'


df1 = pd.read_csv(inpath1, sep=';').fillna('NA')
df2 = pd.read_csv(inpath2, sep=';').fillna('NA')
df3 = pd.read_csv(inpath3, sep=';').fillna('NA')

# compute the majority label from columns elin, lena, and oscar
df1['majority'] = df1[['elin', 'lena', 'oscar']].mode(axis=1)[0]
df2['majority'] = df2[['elin', 'lena', 'oscar']].mode(axis=1)[0]
df3['majority'] = df3[['elin', 'lena', 'oscar']].mode(axis=1)[0]

# save the majority labels
outpath1 = '../tmp/pappa/dim1/annotators_majority/raw_predictions.txt'
outpath2 = '../tmp/pappa/dim2/annotators_majority/raw_predictions.txt'
outpath3 = '../tmp/pappa/dim3/annotators_majority/raw_predictions.txt'

# create the output directory if it does not exist
os.makedirs(os.path.dirname(outpath1), exist_ok=True)
os.makedirs(os.path.dirname(outpath2), exist_ok=True)
os.makedirs(os.path.dirname(outpath3), exist_ok=True)

df1['majority'].to_csv(outpath1, index=False, header=False)
df2['majority'].to_csv(outpath2, index=False, header=False)
df3['majority'].to_csv(outpath3, index=False, header=False)

# %%
# compute the performance of the majority label on dim1
# !python ../main.py \
    --data_file ../data/pappa/human_annotation/dim1.csv \
    --instruction annotators \
    --task_file ../tasks/pappa/dim1.json \
    --prompt_suffix "\\nLabel:" \
    --model_name majority \
    --max_len_model 512 \
    --output_dir ../tmp/pappa/dim1 \
    --evaluation_only True \
    --log_to_file False \
    --raw_predictions_good True
# Out:
# 2023-09-19 20:39:28 [main] Working on ../tmp/pappa/dim1/annotators_majority
# 2023-09-19 20:39:28 [main] Evaluation only. Loading raw predictions.
# 2023-09-19 20:39:28 [main] Gold labels found. Evaluating predictions.
# 2023-09-19 20:39:28 [lm_classifiers] Evaluating predictions...
# 2023-09-19 20:39:28 [lm_classifiers]
#          prediction         gold_elin  ...        gold_oscar          gold_agg
# 0           PASSIVE           PASSIVE  ...           PASSIVE           PASSIVE
# 1                NA           PASSIVE  ...                NA                NA
# 2  ACTIVE_POS_OTHER  ACTIVE_POS_OTHER  ...           PASSIVE  ACTIVE_POS_OTHER
# 3  ACTIVE_POS_OTHER  ACTIVE_POS_OTHER  ...  ACTIVE_POS_OTHER  ACTIVE_POS_OTHER
# 4           PASSIVE           PASSIVE  ...           PASSIVE           PASSIVE
#
# [5 rows x 5 columns]
#
# 2023-09-19 20:39:28 [lm_classifiers] KAPPA:
#          elin    lena   oscar     agg   model  mean_non_agg
# elin   100.00   48.68   49.93   67.28   69.49         49.30
# lena    48.68  100.00   53.37   75.09   74.29         51.02
# oscar   49.93   53.37  100.00   78.19   76.62         51.65
# agg     67.28   75.09   78.19  100.00   96.95         73.52
# model   69.49   74.29   76.62   96.95  100.00         73.47
#
# 2023-09-19 20:39:28 [lm_classifiers] Annotators' mean kappa: 56.37
# 2023-09-19 20:39:28 [lm_classifiers] Model's mean kappa: 79.34
# 2023-09-19 20:39:28 [lm_classifiers] ACCURACY:
#          elin    lena   oscar     agg   model  mean_non_agg
# elin   100.00   60.86   61.71   74.86   76.57         61.29
# lena    60.86  100.00   66.86   81.71   81.14         63.86
# oscar   61.71   66.86  100.00   84.00   82.86         64.29
# agg     74.86   81.71   84.00  100.00   97.71         80.19
# model   76.57   81.14   82.86   97.71  100.00         80.19
#
# 2023-09-19 20:39:28 [lm_classifiers] Annotators' mean accuracy: 67.40
# 2023-09-19 20:39:28 [lm_classifiers] Model's mean accuracy: 84.57
# 2023-09-19 20:39:28 [lm_classifiers] F1:
#          elin    lena   oscar     agg   model  mean_non_agg
# elin   100.00   57.28   57.15   68.85   71.31         57.22
# lena    57.28  100.00   57.93   77.13   74.55         57.60
# oscar   57.15   57.93  100.00   81.33   80.81         57.54
# agg     68.85   77.13   81.33  100.00   94.65         75.77
# model   71.31   74.55   80.81   94.65  100.00         75.56
#
# 2023-09-19 20:39:28 [lm_classifiers] Annotators' mean F1: 62.03
# 2023-09-19 20:39:28 [lm_classifiers] Model's mean F1: 80.33
# 2023-09-19 20:39:28 [main] Done!

# %%
# compute the performance of the majority label on dim2
# !python ../main.py \
    --data_file ../data/pappa/human_annotation/dim2.csv \
    --instruction annotators \
    --task_file ../tasks/pappa/dim2.json \
    --prompt_suffix "\\nLabel:" \
    --model_name majority \
    --max_len_model 512 \
    --output_dir ../tmp/pappa/dim2 \
    --evaluation_only True \
    --log_to_file False \
    --raw_predictions_good True
# Out:
# 2023-09-20 10:30:22 [main] Working on ../tmp/pappa/dim2/annotators_majority
# 2023-09-20 10:30:22 [main] Evaluation only. Loading raw predictions.
# 2023-09-20 10:30:22 [main] Gold labels found. Evaluating predictions.
# 2023-09-20 10:30:22 [lm_classifiers] Evaluating predictions...
# 2023-09-20 10:30:22 [lm_classifiers]
#   prediction gold_elin gold_lena gold_oscar  gold_agg
# 0   EXPLICIT  EXPLICIT  EXPLICIT   EXPLICIT  EXPLICIT
# 1         NA  EXPLICIT        NA         NA        NA
# 2   EXPLICIT  IMPLICIT  EXPLICIT   EXPLICIT  IMPLICIT
# 3   EXPLICIT  EXPLICIT  EXPLICIT   EXPLICIT  EXPLICIT
# 4   EXPLICIT  EXPLICIT  EXPLICIT   EXPLICIT  EXPLICIT
#
# 2023-09-20 10:30:23 [lm_classifiers] KAPPA:
#          elin    lena   oscar     agg   model  mean_non_agg
# elin   100.00   23.55   29.94   94.76   54.07         26.74
# lena    23.55  100.00   29.56   31.08   59.72         26.55
# oscar   29.94   29.56  100.00   36.24   65.26         29.75
# agg     94.76   31.08   36.24  100.00   60.44         54.03
# model   54.07   59.72   65.26   60.44  100.00         59.68
#
# 2023-09-20 10:30:23 [lm_classifiers] Annotators' mean kappa: 34.27
# 2023-09-20 10:30:23 [lm_classifiers] Model's mean kappa: 59.87
# 2023-09-20 10:30:23 [lm_classifiers] ACCURACY:
#          elin    lena   oscar     agg   model  mean_non_agg
# elin   100.00   54.00   55.71   96.57   71.71         54.86
# lena    54.00  100.00   62.57   57.43   81.43         58.29
# oscar   55.71   62.57  100.00   59.14   80.57         59.14
# agg     96.57   57.43   59.14  100.00   75.14         71.05
# model   71.71   81.43   80.57   75.14  100.00         77.90
#
# 2023-09-20 10:30:23 [lm_classifiers] Annotators' mean accuracy: 60.83
# 2023-09-20 10:30:23 [lm_classifiers] Model's mean accuracy: 77.21
# 2023-09-20 10:30:23 [lm_classifiers] F1:
#          elin    lena   oscar     agg   model  mean_non_agg
# elin   100.00   46.40   53.85   96.51   70.09         50.13
# lena    46.40  100.00   50.81   51.68   71.28         48.61
# oscar   53.85   50.81  100.00   57.94   76.86         52.33
# agg     96.51   51.68   57.94  100.00   74.38         68.71
# model   70.09   71.28   76.86   74.38  100.00         72.75
#
# 2023-09-20 10:30:23 [lm_classifiers] Annotators' mean F1: 54.95
# 2023-09-20 10:30:23 [lm_classifiers] Model's mean F1: 73.15
# 2023-09-20 10:30:23 [main] Done!

# %%
# compute the performance of the majority label on dim3
# !python ../main.py \
    --data_file ../data/pappa/human_annotation/dim3.csv \
    --instruction annotators \
    --task_file ../tasks/pappa/dim3.json \
    --prompt_suffix "\\nLabel:" \
    --model_name majority \
    --max_len_model 512 \
    --output_dir ../tmp/pappa/dim3 \
    --evaluation_only True \
    --log_to_file False \
    --raw_predictions_good True
# Out:
# 2023-09-20 10:32:20 [main] Working on ../tmp/pappa/dim3/annotators_majority
# 2023-09-20 10:32:20 [main] Evaluation only. Loading raw predictions.
# 2023-09-20 10:32:20 [main] Gold labels found. Evaluating predictions.
# 2023-09-20 10:32:20 [lm_classifiers] Evaluating predictions...
# 2023-09-20 10:32:20 [lm_classifiers]
#     prediction    gold_elin    gold_lena   gold_oscar gold_agg
# 0        IDEAL        IDEAL        IDEAL  DESCRIPTIVE    IDEAL
# 1           NA  DESCRIPTIVE           NA           NA       NA
# 2  DESCRIPTIVE        IDEAL  DESCRIPTIVE  DESCRIPTIVE    IDEAL
# 3        IDEAL        IDEAL        IDEAL        IDEAL    IDEAL
# 4  DESCRIPTIVE        IDEAL  DESCRIPTIVE  DESCRIPTIVE    IDEAL
#
# 2023-09-20 10:32:20 [lm_classifiers] KAPPA:
#          elin    lena   oscar     agg   model  mean_non_agg
# elin   100.00   34.47   48.82   97.26   66.04         41.64
# lena    34.47  100.00   39.52   38.31   60.64         37.00
# oscar   48.82   39.52  100.00   52.40   79.48         44.17
# agg     97.26   38.31   52.40  100.00   69.36         62.66
# model   66.04   60.64   79.48   69.36  100.00         68.72
#
# 2023-09-20 10:32:20 [lm_classifiers] Annotators' mean kappa: 46.37
# 2023-09-20 10:32:20 [lm_classifiers] Model's mean kappa: 68.88
# 2023-09-20 10:32:20 [lm_classifiers] ACCURACY:
#          elin    lena   oscar     agg   model  mean_non_agg
# elin   100.00   62.57   70.57   98.29   80.29         66.57
# lena    62.57  100.00   71.71   64.29   81.14         67.14
# oscar   70.57   71.71  100.00   72.29   90.00         71.14
# agg     98.29   64.29   72.29  100.00   82.00         78.29
# model   80.29   81.14   90.00   82.00  100.00         83.81
#
# 2023-09-20 10:32:20 [lm_classifiers] Annotators' mean accuracy: 70.79
# 2023-09-20 10:32:20 [lm_classifiers] Model's mean accuracy: 83.36
# 2023-09-20 10:32:20 [lm_classifiers] F1:
#          elin    lena   oscar     agg   model  mean_non_agg
# elin   100.00   56.57   67.09   98.25   78.69         61.83
# lena    56.57  100.00   59.31   58.93   74.07         57.94
# oscar   67.09   59.31  100.00   69.40   86.49         63.20
# agg     98.25   58.93   69.40  100.00   80.84         75.53
# model   78.69   74.07   86.49   80.84  100.00         79.75
#
# 2023-09-20 10:32:20 [lm_classifiers] Annotators' mean F1: 64.62
# 2023-09-20 10:32:20 [lm_classifiers] Model's mean F1: 80.02
# 2023-09-20 10:32:20 [main] Done!
